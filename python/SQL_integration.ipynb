# %%
pip install pyodbc sqlalchemy

# %%
import pandas as pd
import numpy as np
import pyodbc
from sqlalchemy import create_engine

# %%
fraud_data = pd.read_csv('C:\\Videos of Python and HTML\\Project\\Financial_Fraud_Risk_Monitoring_System\\Data\\risk_engineered_transactions.csv')

# %%
import pyodbc

print(pyodbc.drivers())

# %%
import pandas as pd
from sqlalchemy import create_engine

server = 'HAROON'
database = 'FraudRiskMonitor'

connection_string = (
    f"mssql+pyodbc://@{server}/{database}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

engine = create_engine(connection_string, fast_executemany=True)

print("Connection Successful")
# Out:
# Connection Successful

# %%
table_name = 'fraud_transactions'
fraud_data.to_sql(table_name, con = engine, if_exists='replace', index=False, chunksize = 1000)
# Out:
# -556
